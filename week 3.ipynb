# %%
with open('Biodata.txt', 'w') as writefile:
  writefile.write('Nama          : Muhammad Andra Firdaus\n')
  writefile.write('Program Studi : S1 Teknologi Informasi\n')
  writefile.write('NPM           : 2440506053\n')
  writefile.write('Alamat        : Jl.Tentara Pelajar,Tempuran,Magelang\n')
  writefile.write('Hobi          : Drawing\n')
  writefile.write('Email         : muhammadandrafirdaus@gmail.com')

with open('Biodata.txt', 'r') as testwritefile:
  print(testwritefile.read())

with open('Biodata.txt', 'r') as readfile:
  with open('Biodata_singkat.txt', 'w') as writefile:
    for line in readfile:
      writefile.write(line)
# Out:
# Nama          : Muhammad Andra Firdaus
# Program Studi : S1 Teknologi Informasi
# NPM           : 2440506053
# Alamat        : Jl.Tentara Pelajar,Tempuran,Magelang
# Hobi          : Drawing
# Email         : muhammadandrafirdaus@gmail.com

# %%
print ("Selamat datang di Toko Maju Jaya")
print ("Senin, 4 September 2023       13.05")

print ("DAFTAR BELANJA:")
item1 = 'Sabun'
item2 ='Shampo'
item3 = 'Mie instant'
item4 = 'Detergen'
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1+harga2+harga3+harga4
print(item1, "         = Rp"  + str(harga1))
print(item2, '        = Rp' + str(harga2))
print(item3, '   = Rp' + str(harga3))
print(item4, '      = Rp' + str(harga4))

print(" ")
print("Total = Rp "+str(total))


with open('Kuitansi.txt', 'w') as writefile:
  writefile.write('Selamat Datang di Toko Maju Jaya\n')
  writefile.write(' \n')
  writefile.write('Kuitansi - 4 september 2023\n')
  writefile.write(' \n')
  writefile.write(f'{item1}       = Rp {harga1}\n')
  writefile.write(f'{item2}      = Rp {harga2}\n')
  writefile.write(f'{item3} = Rp {harga3}\n')
  writefile.write(f'{item4}    = Rp {harga4}\n')
  writefile.write(' \n')
  writefile.write(f'Total Belanja = Rp {total}')

with open('Kuitansi.txt', 'r') as testwritefile:
  print(testwritefile.read())
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023       13.05
# DAFTAR BELANJA:
# Sabun          = Rp10000
# Shampo         = Rp15000
# Mie instant    = Rp5000
# Detergen       = Rp17500
#
# Total = Rp 47500
# Selamat Datang di Toko Maju Jaya
#
# Kuitansi - 4 september 2023
#
# Sabun       = Rp 10000
# Shampo      = Rp 15000
# Mie instant = Rp 5000
# Detergen    = Rp 17500
#
# Total Belanja = Rp 47500

# %% [markdown]
# f-string: Kita menggunakan f-string untuk menyisipkan nilai variabel secara langsung ke dalam string. Huruf f sebelum tanda kutip menunjukkan bahwa ini adalah f-string. Kurung kurawal: Nilai variabel yang ingin disisipkan diletakkan di dalam kurung kurawal {}.
